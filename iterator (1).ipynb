# %% [markdown]
# **create an iterator from a list of your name containing first 5 whole numbers and print its 1st 2 element using next()**

# %%
Abhishek=[1,2,3,4,5]
iterator = iter(Abhishek)
print(next(iterator))
# Out:
# 1

# %%
text= "Hello"
iterator = iter(text)
print(next(iterator))
print(next(iterator))
print(next(iterator))
print(next(iterator))
print(next(iterator))
# Out:
# H
# e
# l
# l
# o

# %% [markdown]
# **by using for loop**

# %%
data=[1,2,3,4,5]
iterator=iter(data)
for item in iterator :
  print(item)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# **How to you use a for loop to iterate over an iterator**

# %%
letters = iter(["a", "b", "c"])

for letter in letters:
    print(letter)
# Out:
# a
# b
# c

# %% [markdown]
# **How do you use iter() and next() to iterate through a range of numbers?**

# %%
range_iter=iter(range(5))
print(next(range_iter))
print(next(range_iter))
print(next(range_iter))
print(next(range_iter))
print(next(range_iter))
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# **Manually iterate through a tuple using an iterator and a while loop.**

# %%
fruits = ("apple", "banana", "cherry")
fruit_iter = iter(fruits)

while True:
    try:
        print(next(fruit_iter))
    except StopIteration:
        break
# Out:
# apple
# banana
# cherry
